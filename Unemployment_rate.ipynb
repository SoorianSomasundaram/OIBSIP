# %% [markdown]
# ### **Importing Libraries:**

# %%
#importing libraries
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### **Data Collection:**

# %%
# reading of dataset
df = pd.read_csv('Unemployment_Rate_2020.csv')
df
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
# ...

# %%
df.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        267.000000         2.670000e+02
# mean                          12.236929         1.396211e+07
# std                           10.803283         1.336632e+07
# min                            0.500000         1.175420e+05
# 25%                            4.845000         2.838930e+06
# 50%                            9.650000         9.732417e+06
# 75%                           16.755000         2.187869e+07
# max                           75.850000         5.943376e+07
#
#         Estimated Labour Participation Rate (%)   longitude    latitude
# count                                267.000000  267.000000  267.000000
# mean                                  41.681573   22.826048   80.532425
# std                                    7.845419    6.270731    5.831738
# min                                   16.770000   10.850500   71.192400
# ...

# %% [markdown]
# ### **State Analysis:**

# %%
px.histogram(x=' Estimated Unemployment Rate (%)',y='Region',data_frame=df, title='total Unemployment rate in different regions')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### **Pie Chart Analysis on unempolyment rate at every region**

# %%
# Create a pie chart for regional analysis of estimated unemployment rate
fig = px.pie(df, values=' Estimated Unemployment Rate (%)', names='Region.1', color='Region.1', title='Regional Analysis')

# Show the pie chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### **Impact Analysis:**

# %%
px.area(x=' Date', y=' Estimated Unemployment Rate (%)',color=' Date', title='unemployment rate with date and year',data_frame=df)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### **Correlation Analysis Between Participation rate and Estimated Unemployment rate**

# %%
scaler = StandardScaler()

df_std_encoded = df[[' Estimated Labour Participation Rate (%)', ' Estimated Unemployment Rate (%)', ' Estimated Employed']]

scaler.fit_transform(df_std_encoded)
# Out:
# array([[-8.44843834e-02, -6.26625969e-01,  2.00388000e-01],
#        [-9.98086567e-02, -5.94167570e-01,  1.93650783e-01],
#        [-3.19456575e-01, -5.97877102e-01,  1.43846283e-01],
#        [-1.09588642e+00,  7.67230402e-01, -1.96772559e-01],
#        [-6.66806770e-01,  4.81596495e-01, -7.29511611e-02],
#        [ 7.31533172e-01, -8.27868040e-01,  4.37986546e-01],
#        [-3.53936190e-01, -3.61394484e-01,  1.10147677e-01],
#        [-4.91854650e-01, -4.89373312e-01,  9.66677705e-02],
#        [-5.37827470e-01, -5.41306750e-01,  9.43093733e-02],
#        [-5.54428766e-01, -5.23686476e-01,  8.96055463e-02],
#        [ 1.44283486e+00, -7.02671360e-01, -6.82245476e-02],
#        [-1.16409953e-01, -7.25855930e-01, -2.90365113e-01],
#        [ 6.44695623e-01, -6.92470149e-01, -1.81333468e-01],
#        [-1.54922951e+00, -1.09146358e-01, -5.34528704e-01],
#        [ 8.40080108e-01, -2.49181163e-01, -1.94449991e-01],
#        [-8.44312936e-01, -1.07918878e+00, -3.64745170e-01],
# ...

# %%
P_df = ' Estimated Labour Participation Rate (%)'
U_df = ' Estimated Unemployment Rate (%)'

corr_df = df_std_encoded[[P_df] + [U_df]].corr()

Participate_Unemploy_corr = corr_df.loc[P_df,U_df]
Participate_Unemploy_corr
# Out:
# -0.07353988391539262

# %%
heatmap = go.Heatmap(x=corr_df.columns,
                     y=corr_df.columns,
                     z=corr_df.values,
                     colorscale='purples')

layout = go.Layout(title='correlation between unemployment and participation rate')

fig = go.Figure(data=[heatmap],layout=layout)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### **Correlation between unemployment rate and estimated employment**

# %% [markdown]
# #### Standardizing of column estimated employment

# %%
E_df = ' Estimated Employed'
U_df = ' Estimated Unemployment Rate (%)'

corr_df = df_std_encoded[[E_df] + [U_df]].corr()

corr_df.loc[E_df,U_df]
# Out:
# -0.2451759144921189

# %%
px.imshow(corr_df,color_continuous_scale = 'viridis',title="Correlation between estimated employed and unemployment rate")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
